# %%
import numpy as np
import os
import boto3
import tensorflow as tf

# %%
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()

# %%
bucket = 'demo-saeed'
prefix = 'fraudcredit-keras1_8m_9'
dataset_train_name = 'creditcard1_8m_train.csv'
dataset_test_name='creditcard1_8m_test.csv'

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'data/train/{}'.format(dataset_train_name))).upload_file('data/{}'.format(dataset_train_name))

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'data/test/{}'.format(dataset_test_name))).upload_file('data/{}'.format(dataset_test_name))

# %%
# %%bash
#
# for i in {0..8}; do
#     aws s3 cp s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_${i}.csv
# done
# Out:
# copy: s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv to s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_0.csv
# copy: s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv to s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_1.csv
# copy: s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv to s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_2.csv
# copy: s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv to s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_3.csv
# copy: s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv to s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_4.csv
# copy: s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv to s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_5.csv
# copy: s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv to s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_6.csv
# copy: s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv to s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_7.csv
# copy: s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test.csv to s3://demo-saeed/fraudcredit-keras1_8m_9/data/test/creditcard1_8m_test_8.csv

# %%
# train_input = sagemaker_session.upload_data('data', key_prefix="{}/{}/{}".format(bucket_name, prefix, 'data') )
# train_input

# %%
data_location = 's3://{}/{}/{}'.format(bucket, prefix, 'data/train',dataset_train_name)
s3_input_train = sagemaker.s3_input(s3_data = data_location, content_type='csv')
s3_input_train.config
# Out:
# {'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix',
#    'S3Uri': 's3://demo-saeed/fraudcredit-keras1_8m_9/data/train',
#    'S3DataDistributionType': 'FullyReplicated'}},
#  'ContentType': 'csv'}

# %%
train_input = 's3://{}/{}/data/train/{}'.format(bucket,prefix,dataset_train_name)
train_input
# Out:
# 's3://demo-saeed/fraudcredit-keras1_8m_9/data/train/creditcard1_8m_train.csv'

# %%
# import pandas as pd
# df = pd.read_csv(train_input, sep=',',  nrows=1)
# df.head()

# %%
from sagemaker.tensorflow import TensorFlow

tf_estimator = TensorFlow(entry_point='main.py', 
                          role=role,
                          train_instance_count=1, 
                          train_instance_type='ml.p3.2xlarge',
                          framework_version='1.12', 
                          py_version='py3',
                          script_mode=True,
                          hyperparameters={'epochs': 1}
                         )

# %%
tf_estimator.fit({'train': s3_input_train})
# Out:
# 2020-03-08 01:37:15 Starting - Starting the training job...
# 2020-03-08 01:37:17 Starting - Launching requested ML instances......
# 2020-03-08 01:38:21 Starting - Preparing the instances for training...
# 2020-03-08 01:39:16 Downloading - Downloading input data.........
# 2020-03-08 01:40:42 Training - Downloading the training image...
# 2020-03-08 01:41:03 Training - Training image download completed. Training in progress.2020-03-08 01:41:07,149 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-03-08 01:41:07,594 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/model",
#         "epochs": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "ContentType": "csv",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/source/sourcedir.tar.gz",
#     "module_name": "main",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "main.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":1,"model_dir":"s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/model"}
# SM_USER_ENTRY_POINT=main.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=main
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":1,"model_dir":"s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"csv","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/source/sourcedir.tar.gz","module_name":"main","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"main.py"}
# SM_USER_ARGS=["--epochs","1","--model_dir","s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/model
# SM_HP_EPOCHS=1
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python main.py --epochs 1 --model_dir s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/model
#
#
# Using TensorFlow backend.
# (80, 2108909)
# Train on 80 samples, validate on 20 samples
# Epoch 1/2
# 32/80 [===========>..................] - ETA: 13s - loss: 0.8376 - acc: 0.0000e+00
# 64/80 [=======================>......] - ETA: 3s - loss: 0.7148 - acc: 0.0000e+00
# 80/80 [==============================] - 17s 209ms/step - loss: 0.7743 - acc: 0.0000e+00 - val_loss: 0.6597 - val_acc: 0.0000e+00
# Epoch 2/2
# 32/80 [===========>..................] - ETA: 5s - loss: 0.7296 - acc: 0.0000e+00
# 64/80 [=======================>......] - ETA: 1s - loss: 0.8156 - acc: 0.0000e+00
# 80/80 [==============================] - 12s 145ms/step - loss: 0.7820 - acc: 0.0000e+00 - val_loss: 0.6595 - val_acc: 0.0000e+00
#
# 2020-03-08 01:49:13 Uploading - Uploading generated training modelWARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/simple_save.py:85: calling SavedModelBuilder.add_meta_graph_and_variables (from tensorflow.python.saved_model.builder_impl) with legacy_init_op is deprecated and will be removed in a future version.
# Instructions for updating:
# Pass your op to the equivalent parameter main_op instead.
# 2020-03-08 01:49:12,530 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-03-08 01:50:55 Completed - Training job completed
# Training seconds: 699
# Billable seconds: 699

# %%
tf_estimator.model_dir
# Out:
# 's3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402/model'

# %% [markdown]
# # Prediciton using endpoint high-level sdk

# %%
# import time

# tf_endpoint_name = 'keras-tf-fmnist-'+time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())
# tf_predictor = tf_estimator.deploy(initial_instance_count=1,
#                          instance_type='local',        # $0.134/hour in eu-west-1
#                          endpoint_name=tf_endpoint_name)     # = 80% discount!

# %%
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split
# RANDOM_SEED = 42
# LABELS = ["Normal", "Fraud"]
# data = df.drop(['Time'], axis=1)

# data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))
# X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
# X_train = X_train[X_train.Class == 0]
# X_train = X_train.drop(['Class'], axis=1)

# y_test = X_test['Class']
# X_test = X_test.drop(['Class'], axis=1)

# batch_file = 'batch_data.csv'
# X_test.to_csv(batch_file,index=False,header=False)
# #sess.upload_data(batch_file, key_prefix='{}/batch'.format(prefix))
# boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'batch/batch_data.csv')).upload_file('batch_data.csv')

# X_train = X_train.values
# X_test = X_test.values
# print(X_train.shape)

# %%
# predictions = tf_predictor.predict(X_test)['predictions']
# mse = np.mean(np.power(X_test - predictions, 2), axis=1)
# error_df = pd.DataFrame({'reconstruction_error': mse,
#                         'true_class': y_test})
# error_df.head(20)

# %% [markdown]
# # Prediciton using Tensorflow Serving

# %%
# !aws s3 cp s3://sagemaker-us-east-1-079329190341/sagemaker-tensorflow-scriptmode-2020-03-06-16-23-30-671/model.tar.gz model.tar.gz
# !tar -xf model.tar.gz

# %%
# sess = tf.compat.v1.Session()
# loaded = tf.saved_model.load(export_dir='SavedModels/1/', tags={'serve'},sess=sess )
# loaded.signature_def

# %%
# !saved_model_cli show --dir SavedModels/1/ --tag_set serve --all

# %%
# %%bash
# mkdir -p tmp/tfserving
# cd tmp/tfserving
# git clone --depth=1 https://github.com/tensorflow/serving
# cd tmp/tfserving
# docker pull tensorflow/serving:latest

# %%
# !docker run --rm -p 8501:8501 \
#     --mount type=bind,source=$(pwd),target=$(pwd) \
#     -e MODEL_BASE_PATH=$(pwd)/SavedModels \
#     -e MODEL_NAME=autoencodermodel -t tensorflow/serving:latest

# %%
# %%bash
# cd /tmp/tfserving/
# curl http://localhost:8501/v1/models/autoencodermodel

# %%
# !curl -d '{"instances": [[1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0], \
# [1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0,0.0, 1.0,2.0,5.0,2.0]]}' -X POST http://localhost:8501/v1/models/autoencodermodel:predict

# %% [markdown]
# # Prediction using Batch Transform

# %%
output_path='s3://{}/{}/batch_output/'.format(bucket, prefix)
output_path
# Out:
# 's3://demo-saeed/fraudcredit-keras1_8m_9/batch_output/'

# %%
input_location
# Out:
# 's3://demo-saeed/fraudcredit-keras1_8m_9/data/test'

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'data/test2/df1_5m.ext')).upload_file('data/df1_5m.ext')

# %%
prefix
# Out:
# 'fraudcredit-keras1_8m_9'

# %%
# !aws s3 ls s3://demo-saeed/fraudcredit-keras1_8m_9/data/test
# Out:
#                            PRE test/
#                            PRE test2/

# %%
env = {'SAGEMAKER_TFS_ENABLE_BATCHING': 'true', 'SAGEMAKER_TFS_BATCH_TIMEOUT_MICROS': '50000','SAGEMAKER_TFS_MAX_BATCH_SIZE': '16'}

sm_transformer = tf_estimator.transformer(instance_count=2,
                                          instance_type='ml.p3.2xlarge', 
                                          max_concurrent_transforms=2,
                                          max_payload=40,
                                          strategy='MultiRecord', #
                                          output_path='s3://{}/{}/batch_output/'.format(bucket, prefix),
                                          env=env)
# start a transform job
input_location = 's3://{}/{}/data/test'.format(bucket, prefix) # use input data without ID column
sm_transformer.transform(input_location, 
                         data_type='S3Prefix',
                         content_type='text/csv', 
                         #content_type='application/x-recordio-protobuf', 
                         split_type='Line' #RecordIO
                        )
sm_transformer.wait()
# Out:
# WARNING:sagemaker:Using already existing model: sagemaker-tensorflow-scriptmode-2020-03-08-01-37-15-402
# .......................INFO:__main__:starting services
# INFO:__main__:using default model name: model
# INFO:__main__:tensorflow serving model config:
# model_config_list: {
#   config: {
#     name: "model",
#     base_path: "/opt/ml/model",
#     model_platform: "tensorflow"
#   }
# }
#
#
# INFO:__main__:nginx config:
# load_module modules/ngx_http_js_module.so;
#
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr info;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/json;
#   access_log /dev/stdout combined;
#   js_include tensorflow-serving.js;
#
#   upstream tfs_upstream {
#     server localhost:10001;
#   }
#
#   upstream gunicorn_upstream {
#     server unix:/tmp/gunicorn.sock fail_timeout=1;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     client_body_buffer_size 100m;
#     subrequest_output_buffer_size 100m;
#
#     set $tfs_version 1.12;
#     set $default_tfs_model model;
#
#     location /tfs {
#         rewrite ^/tfs/(.*) /$1  break;
#         proxy_redirect off;
#         proxy_pass_request_headers off;
#         proxy_set_header Content-Type 'application/json';
#         proxy_set_header Accept 'application/json';
#         proxy_pass http://tfs_upstream;
#     }
#
#     location /ping {
#         js_content ping;
#     }
#
#     location /invocations {
#         js_content invocations;
#     }
#
#     location ~ ^/models/(.*)/invoke {
#         js_content invocations;
#     }
#
#     location /models {
#         proxy_pass http://gunicorn_upstream/models;
#     }
#
#     location / {
#         return 404 '{"error": "Not Found"}';
#     }
#
#     keepalive_timeout 3;
#   }
# }
#
#
# INFO:__main__:batching is enabled
# WARNING:__main__:num_batch_threads defaulted to 8,the number of CPUs. Set SAGEMAKER_TFS_NUM_BATCH_THREADS to override default.
# max_enqueued_batches defaulted to 100000000. Set SAGEMAKER_TFS_MAX_ENQUEUED_BATCHES to override default. Tuning this parameter may be necessary to tune out-of-memory errors occur.
#
# INFO:__main__:batching config:
# max_batch_size { value: 16 }
# batch_timeout_micros { value: 50000 }
# num_batch_threads { value: 8 }
# max_enqueued_batches { value: 100000000 }
#
#
# INFO:__main__:tensorflow version info:
# TensorFlow ModelServer: 1.12.0-rc0+dev.sha.87470f0
# TensorFlow Library: 1.12.0
# INFO:__main__:tensorflow serving command: tensorflow_model_server --port=10000 --rest_api_port=10001 --model_config_file=/sagemaker/model-config.cfg --enable_batching=true --batching_parameters_file=/sagemaker/batching-config.cfg
# INFO:__main__:started tensorflow serving (pid: 10)
# INFO:__main__:nginx version info:
# nginx version: nginx/1.16.1
# built by gcc 5.4.0 20160609 (Ubuntu 5.4.0-6ubuntu1~16.04.11)
# built with OpenSSL 1.0.2g  1 Mar 2016
# TLS SNI support enabled
# configure arguments: --prefix=/etc/nginx --sbin-path=/usr/sbin/nginx --modules-path=/usr/lib/nginx/modules --conf-path=/etc/nginx/nginx.conf --error-log-path=/var/log/nginx/error.log --http-log-path=/var/log/nginx/access.log --pid-path=/var/run/nginx.pid --lock-path=/var/run/nginx.lock --http-client-body-temp-path=/var/cache/nginx/client_temp --http-proxy-temp-path=/var/cache/nginx/proxy_temp --http-fastcgi-temp-path=/var/cache/nginx/fastcgi_temp --http-uwsgi-temp-path=/var/cache/nginx/uwsgi_temp --http-scgi-temp-path=/var/cache/nginx/scgi_temp --user=nginx --group=nginx --with-compat --with-file-aio --with-threads --with-http_addition_module --with-http_auth_request_module --with-http_dav_module --with-http_flv_module --with-http_gunzip_module --with-http_gzip_static_module --with-http_mp4_module --with-http_random_index_module --with-http_realip_module --with-http_secure_link_module --with-http_slice_module --with-http_ssl_module --with-http_stub_status_module --with-http_sub_module --with-http_v2_module --with-mail --with-mail_ssl_module --with-stream --with-stream_realip_module --with-stream_ssl_module --with-stream_ssl_preread_module --with-cc-opt='-g -O2 -fPIE -fstack-protector-strong -Wformat -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -fPIC' --with-ld-opt='-Wl,-Bsymbolic-functions -fPIE -pie -Wl,-z,relro -Wl,-z,now -Wl,--as-needed -pie'
# INFO:__main__:started nginx (pid: 12)
# 2020/03/08 12:56:42 [notice] 12#12: using the "epoll" event method
# 2020/03/08 12:56:42 [notice] 12#12: nginx/1.16.1
# 2020/03/08 12:56:42 [notice] 12#12: built by gcc 5.4.0 20160609 (Ubuntu 5.4.0-6ubuntu1~16.04.11)
# 2020/03/08 12:56:42 [notice] 12#12: OS: Linux 4.14.154-99.181.amzn1.x86_64
# 2020/03/08 12:56:42 [notice] 12#12: getrlimit(RLIMIT_NOFILE): 65536:99999
# 2020/03/08 12:56:42 [notice] 12#12: start worker processes
# 2020/03/08 12:56:42 [notice] 12#12: start worker process 13
# 2020/03/08 12:56:42 [notice] 12#12: start worker process 14
# 2020/03/08 12:56:42 [notice] 12#12: start worker process 15
# 2020/03/08 12:56:42 [notice] 12#12: start worker process 16
# 2020/03/08 12:56:42 [notice] 12#12: start worker process 17
# 2020/03/08 12:56:42 [notice] 12#12: start worker process 18
# 2020/03/08 12:56:42 [notice] 12#12: start worker process 19
# 2020/03/08 12:56:42 [notice] 12#12: start worker process 20
# 2020-03-08 12:56:42.432833: I tensorflow_serving/model_servers/server_core.cc:461] Adding/updating models.
# 2020-03-08 12:56:42.432881: I tensorflow_serving/model_servers/server_core.cc:558]  (Re-)adding model: model
# 2020-03-08 12:56:42.533242: I tensorflow_serving/core/basic_manager.cc:739] Successfully reserved resources to load servable {name: model version: 1}
# 2020-03-08 12:56:42.533297: I tensorflow_serving/core/loader_harness.cc:66] Approving load for servable version {name: model version: 1}
# 2020-03-08 12:56:42.533334: I tensorflow_serving/core/loader_harness.cc:74] Loading servable version {name: model version: 1}
# 2020-03-08 12:56:42.533369: I external/org_tensorflow/tensorflow/contrib/session_bundle/bundle_shim.cc:363] Attempting to load native SavedModelBundle in bundle-shim from: /opt/ml/model/1
# 2020-03-08 12:56:42.533395: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:31] Reading SavedModel from: /opt/ml/model/1
# 2020-03-08 12:56:42.540141: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:54] Reading meta graph with tags { serve }
# 2020-03-08 12:56:42.546885: I external/org_tensorflow/tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-03-08 12:56:42.955146: I external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-08 12:56:42.956232: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1e.0
# totalMemory: 15.75GiB freeMemory: 15.44GiB
# 2020-03-08 12:56:42.956270: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2020-03-08 12:56:43.875050: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-08 12:56:43.875105: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2020-03-08 12:56:43.875114: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# 2020-03-08 12:56:43.875242: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14855 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# 2020-03-08 12:56:43.920748: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:162] Restoring SavedModel bundle.
# 2020-03-08 12:56:45.631179: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:138] Running MainOp with key legacy_init_op on SavedModel bundle.
# 2020-03-08 12:56:45.631253: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:259] SavedModel load for tags { serve }; Status: success. Took 3097847 microseconds.
# 2020-03-08 12:56:45.631272: I tensorflow_serving/servables/tensorflow/saved_model_bundle_factory.cc:100] Wrapping session to perform batch processing
# 2020-03-08 12:56:45.631289: I tensorflow_serving/servables/tensorflow/bundle_factory_util.cc:153] Wrapping session to perform batch processing
# 2020-03-08 12:56:45.631368: I tensorflow_serving/servables/tensorflow/saved_model_warmup.cc:83] No warmup data file found at /opt/ml/model/1/assets.extra/tf_serving_warmup_requests
# 2020-03-08 12:56:45.631554: I tensorflow_serving/core/loader_harness.cc:86] Successfully loaded servable version {name: model version: 1}
# 2020-03-08 12:56:45.634790: I tensorflow_serving/model_servers/server.cc:286] Running gRPC ModelServer at 0.0.0.0:10000 ...
# [warn] getaddrinfo: address family for nodename not supported
# 2020-03-08 12:56:45.636963: I tensorflow_serving/model_servers/server.cc:302] Exporting HTTP/REST API at:localhost:10001 ...
# [evhttp_server.cc : 237] RAW: Entering the event loop ...
# INFO:__main__:starting services
# INFO:__main__:using default model name: model
# INFO:__main__:tensorflow serving model config:
# model_config_list: {
#   config: {
#     name: "model",
#     base_path: "/opt/ml/model",
#     model_platform: "tensorflow"
#   }
# }
#
#
# INFO:__main__:nginx config:
# load_module modules/ngx_http_js_module.so;
#
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr info;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/json;
#   access_log /dev/stdout combined;
#   js_include tensorflow-serving.js;
#
#   upstream tfs_upstream {
#     server localhost:10001;
#   }
#
#   upstream gunicorn_upstream {
#     server unix:/tmp/gunicorn.sock fail_timeout=1;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     client_body_buffer_size 100m;
#     subrequest_output_buffer_size 100m;
#
#     set $tfs_version 1.12;
#     set $default_tfs_model model;
#
#     location /tfs {
#         rewrite ^/tfs/(.*) /$1  break;
#         proxy_redirect off;
#         proxy_pass_request_headers off;
#         proxy_set_header Content-Type 'application/json';
#         proxy_set_header Accept 'application/json';
#         proxy_pass http://tfs_upstream;
#     }
#
#     location /ping {
#         js_content ping;
#     }
#
#     location /invocations {
#         js_content invocations;
#     }
#
#     location ~ ^/models/(.*)/invoke {
#         js_content invocations;
#     }
#
#     location /models {
#         proxy_pass http://gunicorn_upstream/models;
#     }
#
#     location / {
#         return 404 '{"error": "Not Found"}';
#     }
#
#     keepalive_timeout 3;
#   }
# }
#
#
# INFO:__main__:batching is enabled
# WARNING:__main__:num_batch_threads defaulted to 8,the number of CPUs. Set SAGEMAKER_TFS_NUM_BATCH_THREADS to override default.
# max_enqueued_batches defaulted to 100000000. Set SAGEMAKER_TFS_MAX_ENQUEUED_BATCHES to override default. Tuning this parameter may be necessary to tune out-of-memory errors occur.
#
# INFO:__main__:batching config:
# max_batch_size { value: 16 }
# batch_timeout_micros { value: 50000 }
# num_batch_threads { value: 8 }
# max_enqueued_batches { value: 100000000 }
#
#
# INFO:__main__:tensorflow version info:
# TensorFlow ModelServer: 1.12.0-rc0+dev.sha.87470f0
# TensorFlow Library: 1.12.0
# INFO:__main__:tensorflow serving command: tensorflow_model_server --port=10000 --rest_api_port=10001 --model_config_file=/sagemaker/model-config.cfg --enable_batching=true --batching_parameters_file=/sagemaker/batching-config.cfg
# INFO:__main__:started tensorflow serving (pid: 10)
# INFO:__main__:nginx version info:
# nginx version: nginx/1.16.1
# built by gcc 5.4.0 20160609 (Ubuntu 5.4.0-6ubuntu1~16.04.11)
# built with OpenSSL 1.0.2g  1 Mar 2016
# TLS SNI support enabled
# configure arguments: --prefix=/etc/nginx --sbin-path=/usr/sbin/nginx --modules-path=/usr/lib/nginx/modules --conf-path=/etc/nginx/nginx.conf --error-log-path=/var/log/nginx/error.log --http-log-path=/var/log/nginx/access.log --pid-path=/var/run/nginx.pid --lock-path=/var/run/nginx.lock --http-client-body-temp-path=/var/cache/nginx/client_temp --http-proxy-temp-path=/var/cache/nginx/proxy_temp --http-fastcgi-temp-path=/var/cache/nginx/fastcgi_temp --http-uwsgi-temp-path=/var/cache/nginx/uwsgi_temp --http-scgi-temp-path=/var/cache/nginx/scgi_temp --user=nginx --group=nginx --with-compat --with-file-aio --with-threads --with-http_addition_module --with-http_auth_request_module --with-http_dav_module --with-http_flv_module --with-http_gunzip_module --with-http_gzip_static_module --with-http_mp4_module --with-http_random_index_module --with-http_realip_module --with-http_secure_link_module --with-http_slice_module --with-http_ssl_module --with-http_stub_status_module --with-http_sub_module --with-http_v2_module --with-mail --with-mail_ssl_module --with-stream --with-stream_realip_module --with-stream_ssl_module --with-stream_ssl_preread_module --with-cc-opt='-g -O2 -fPIE -fstack-protector-strong -Wformat -Werror=format-security -Wp,-D_FORTIFY_SOURCE=2 -fPIC' --with-ld-opt='-Wl,-Bsymbolic-functions -fPIE -pie -Wl,-z,relro -Wl,-z,now -Wl,--as-needed -pie'
# INFO:__main__:started nginx (pid: 12)
# 2020/03/08 12:56:43 [notice] 12#12: using the "epoll" event method
# 2020/03/08 12:56:43 [notice] 12#12: nginx/1.16.1
# 2020/03/08 12:56:43 [notice] 12#12: built by gcc 5.4.0 20160609 (Ubuntu 5.4.0-6ubuntu1~16.04.11)
# 2020/03/08 12:56:43 [notice] 12#12: OS: Linux 4.14.154-99.181.amzn1.x86_64
# 2020/03/08 12:56:43 [notice] 12#12: getrlimit(RLIMIT_NOFILE): 65536:99999
# 2020/03/08 12:56:43 [notice] 12#12: start worker processes
# 2020/03/08 12:56:43 [notice] 12#12: start worker process 13
# 2020/03/08 12:56:43 [notice] 12#12: start worker process 14
# 2020/03/08 12:56:43 [notice] 12#12: start worker process 15
# 2020/03/08 12:56:43 [notice] 12#12: start worker process 16
# 2020/03/08 12:56:43 [notice] 12#12: start worker process 17
# 2020/03/08 12:56:43 [notice] 12#12: start worker process 18
# 2020/03/08 12:56:43 [notice] 12#12: start worker process 19
# 2020/03/08 12:56:43 [notice] 12#12: start worker process 20
# 2020-03-08 12:56:43.444545: I tensorflow_serving/model_servers/server_core.cc:461] Adding/updating models.
# 2020-03-08 12:56:43.444595: I tensorflow_serving/model_servers/server_core.cc:558]  (Re-)adding model: model
# 2020-03-08 12:56:43.545013: I tensorflow_serving/core/basic_manager.cc:739] Successfully reserved resources to load servable {name: model version: 1}
# 2020-03-08 12:56:43.545064: I tensorflow_serving/core/loader_harness.cc:66] Approving load for servable version {name: model version: 1}
# 2020-03-08 12:56:43.545078: I tensorflow_serving/core/loader_harness.cc:74] Loading servable version {name: model version: 1}
# 2020-03-08 12:56:43.545102: I external/org_tensorflow/tensorflow/contrib/session_bundle/bundle_shim.cc:363] Attempting to load native SavedModelBundle in bundle-shim from: /opt/ml/model/1
# 2020-03-08 12:56:43.545115: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:31] Reading SavedModel from: /opt/ml/model/1
# 2020-03-08 12:56:43.553511: I external/org_tensorflow/tensorflow/cc/saved_model/reader.cc:54] Reading meta graph with tags { serve }
# 2020-03-08 12:56:43.562447: I external/org_tensorflow/tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-03-08 12:56:43.982553: I external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-08 12:56:43.983612: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla V100-SXM2-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:00:1e.0
# totalMemory: 15.75GiB freeMemory: 15.44GiB
# 2020-03-08 12:56:43.983645: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2020-03-08 12:56:44.911774: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-08 12:56:44.911826: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2020-03-08 12:56:44.911836: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# 2020-03-08 12:56:44.912010: I external/org_tensorflow/tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14854 MB memory) -> physical GPU (device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:1e.0, compute capability: 7.0)
# 2020-03-08 12:56:44.962513: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:162] Restoring SavedModel bundle.
# 2020-03-08 12:56:46.448853: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:138] Running MainOp with key legacy_init_op on SavedModel bundle.
# 2020-03-08 12:56:46.448944: I external/org_tensorflow/tensorflow/cc/saved_model/loader.cc:259] SavedModel load for tags { serve }; Status: success. Took 2903813 microseconds.
# 2020-03-08 12:56:46.448968: I tensorflow_serving/servables/tensorflow/saved_model_bundle_factory.cc:100] Wrapping session to perform batch processing
# 2020-03-08 12:56:46.448994: I tensorflow_serving/servables/tensorflow/bundle_factory_util.cc:153] Wrapping session to perform batch processing
# 2020-03-08 12:56:46.449074: I tensorflow_serving/servables/tensorflow/saved_model_warmup.cc:83] No warmup data file found at /opt/ml/model/1/assets.extra/tf_serving_warmup_requests
# 2020-03-08 12:56:46.449224: I tensorflow_serving/core/loader_harness.cc:86] Successfully loaded servable version {name: model version: 1}
# 2020-03-08 12:56:46.453258: I tensorflow_serving/model_servers/server.cc:286] Running gRPC ModelServer at 0.0.0.0:10000 ...
# [warn] getaddrinfo: address family for nodename not supported
# [evhttp_server.cc : 237] RAW: Entering the event loop ...
# 2020-03-08 12:56:46.455868: I tensorflow_serving/model_servers/server.cc:302] Exporting HTTP/REST API at:localhost:10001 ...
# 169.254.255.130 - - [08/Mar/2020:12:56:53 +0000] "GET /ping HTTP/1.1" 200 3 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:56:53 +0000] "GET /execution-parameters HTTP/1.1" 404 22 "-" "Go-http-client/1.1"
# 2020/03/08 12:56:53 [info] 16#16: *2 client 169.254.255.130 closed keepalive connection
# 169.254.255.130 - - [08/Mar/2020:12:56:53 +0000] "GET /ping HTTP/1.1" 200 3 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:56:53 +0000] "GET /execution-parameters HTTP/1.1" 404 22 "-" "Go-http-client/1.1"
# 2020/03/08 12:56:53 [info] 16#16: *2 client 169.254.255.130 closed keepalive connection
# 2020-03-08T12:56:53.161:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=40, BatchStrategy=MULTI_RECORD
# 2020-03-08T12:56:53.161:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=40, BatchStrategy=MULTI_RECORD
# 169.254.255.130 - - [08/Mar/2020:12:56:59 +0000] "GET /ping HTTP/1.1" 200 3 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:56:59 +0000] "GET /execution-parameters HTTP/1.1" 404 22 "-" "Go-http-client/1.1"
# 2020/03/08 12:56:59 [info] 20#20: *2 client 169.254.255.130 closed keepalive connection
# 2020/03/08 12:57:01 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/00/0000000001 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 12:57:01 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/00/0000000002 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 12:57:01 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/00/0000000001 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 12:57:01 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/00/0000000002 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:01 +0000] "POST /invocations HTTP/1.1" 200 18090294 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:57:01 +0000] "POST /invocations HTTP/1.1" 200 18378657 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:57:01 +0000] "POST /invocations HTTP/1.1" 200 18090294 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:57:01 +0000] "POST /invocations HTTP/1.1" 200 18378657 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:03 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/00/0000000003 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:03 +0000] "POST /invocations HTTP/1.1" 200 18113357 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:03 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/00/0000000003 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:03 +0000] "POST /invocations HTTP/1.1" 200 18113357 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:03 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/4/00/0000000004 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:03 +0000] "POST /invocations HTTP/1.1" 200 18597812 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:03 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/4/00/0000000004 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:03 +0000] "POST /invocations HTTP/1.1" 200 18597812 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:05 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/5/00/0000000005 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 12:57:05 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/5/00/0000000005 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:05 +0000] "POST /invocations HTTP/1.1" 200 18326078 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:05 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/6/00/0000000006 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:05 +0000] "POST /invocations HTTP/1.1" 200 18326078 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:05 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/6/00/0000000006 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020-03-08T12:56:59.817:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=40, BatchStrategy=MULTI_RECORD
# 169.254.255.130 - - [08/Mar/2020:12:57:07 +0000] "POST /invocations HTTP/1.1" 200 18202237 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:57:07 +0000] "POST /invocations HTTP/1.1" 200 18202237 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:07 [warn] 20#20: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/00/0000000001 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 12:57:07 [warn] 17#17: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/00/0000000002 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:07 +0000] "POST /invocations HTTP/1.1" 200 18090294 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:57:07 +0000] "POST /invocations HTTP/1.1" 200 18378657 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:07 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/00/0000000008 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 12:57:07 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/00/0000000008 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:07 +0000] "POST /invocations HTTP/1.1" 200 18343048 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:57:07 +0000] "POST /invocations HTTP/1.1" 200 18343048 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:09 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/00/0000000009 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:09 +0000] "POST /invocations HTTP/1.1" 200 18392397 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:09 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/00/0000000009 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:09 +0000] "POST /invocations HTTP/1.1" 200 18392397 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:09 [warn] 20#20: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/00/0000000003 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:09 +0000] "POST /invocations HTTP/1.1" 200 18113357 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:10 [warn] 17#17: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/4/00/0000000004 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:10 +0000] "POST /invocations HTTP/1.1" 200 18597812 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:09 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/01/0000000010 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:10 +0000] "POST /invocations HTTP/1.1" 200 18265088 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:09 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/01/0000000010 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:10 +0000] "POST /invocations HTTP/1.1" 200 18265088 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:11 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/01/0000000011 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:11 +0000] "POST /invocations HTTP/1.1" 200 18685851 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:11 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/01/0000000011 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:11 +0000] "POST /invocations HTTP/1.1" 200 18685851 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:11 [warn] 20#20: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/5/00/0000000005 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:11 +0000] "POST /invocations HTTP/1.1" 200 18326078 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:12 [warn] 17#17: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/6/00/0000000006 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:12 +0000] "POST /invocations HTTP/1.1" 200 18249855 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:12 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/01/0000000012 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:12 +0000] "POST /invocations HTTP/1.1" 200 18392397 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:12 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/01/0000000012 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:12 +0000] "POST /invocations HTTP/1.1" 200 18392397 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:12 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/01/0000000013 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:13 +0000] "POST /invocations HTTP/1.1" 200 18402837 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:12 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/01/0000000013 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:13 +0000] "POST /invocations HTTP/1.1" 200 18402837 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:14 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/4/01/0000000014 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:14 +0000] "POST /invocations HTTP/1.1" 200 18098437 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:14 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/4/01/0000000014 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:14 +0000] "POST /invocations HTTP/1.1" 200 18098437 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:14 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/5/01/0000000015 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:14 +0000] "POST /invocations HTTP/1.1" 200 18647717 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:14 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/5/01/0000000015 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:14 +0000] "POST /invocations HTTP/1.1" 200 18647717 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:13 [warn] 17#17: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/7/00/0000000007 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:13 +0000] "POST /invocations HTTP/1.1" 200 18202237 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:14 [warn] 20#20: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/00/0000000008 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:14 +0000] "POST /invocations HTTP/1.1" 200 18343048 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:15 [warn] 17#17: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/00/0000000009 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:15 +0000] "POST /invocations HTTP/1.1" 200 18392397 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:16 [warn] 20#20: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/01/0000000010 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:16 +0000] "POST /invocations HTTP/1.1" 200 18265088 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:16 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/7/01/0000000017 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:17 +0000] "POST /invocations HTTP/1.1" 200 18371880 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:16 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/7/01/0000000017 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:17 +0000] "POST /invocations HTTP/1.1" 200 18371880 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:17 [warn] 17#17: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/01/0000000011 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:17 +0000] "POST /invocations HTTP/1.1" 200 18685851 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:18 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/01/0000000018 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:18 +0000] "POST /invocations HTTP/1.1" 200 18084437 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:18 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/01/0000000018 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:18 +0000] "POST /invocations HTTP/1.1" 200 18084437 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:18 [warn] 20#20: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/01/0000000012 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:18 +0000] "POST /invocations HTTP/1.1" 200 18392397 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:19 [warn] 17#17: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/01/0000000013 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:19 +0000] "POST /invocations HTTP/1.1" 200 18402837 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:19 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/01/0000000019 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:19 +0000] "POST /invocations HTTP/1.1" 200 18410783 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:19 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/01/0000000019 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:19 +0000] "POST /invocations HTTP/1.1" 200 18410783 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:20 [warn] 20#20: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/4/01/0000000014 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 12:57:20 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/02/0000000020 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:20 +0000] "POST /invocations HTTP/1.1" 200 18504930 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:20 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/02/0000000020 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:20 +0000] "POST /invocations HTTP/1.1" 200 18504930 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:57:20 +0000] "POST /invocations HTTP/1.1" 200 18098437 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:21 [warn] 17#17: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/5/01/0000000015 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:21 +0000] "POST /invocations HTTP/1.1" 200 18647717 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:20 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/02/0000000021 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:21 +0000] "POST /invocations HTTP/1.1" 200 18373830 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:20 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/02/0000000021 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:21 +0000] "POST /invocations HTTP/1.1" 200 18373830 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:22 [warn] 20#20: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/6/01/0000000016 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 12:57:22 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/02/0000000022 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:22 +0000] "POST /invocations HTTP/1.1" 200 17971489 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:22 [warn] 18#18: *4 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/02/0000000022 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:22 +0000] "POST /invocations HTTP/1.1" 200 17971489 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:57:22 +0000] "POST /invocations HTTP/1.1" 200 18557656 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:23 [warn] 17#17: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/7/01/0000000017 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:23 +0000] "POST /invocations HTTP/1.1" 200 18371880 "-" "Go-http-client/1.1"
# 2020/03/08 12:57:23 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/02/0000000023 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 12:57:23 [warn] 16#16: *3 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/02/0000000023 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:12:57:23 +0000] "POST /invocations HTTP/1.1" 200 19369332 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:12:57:23 +0000] "POST /invocations HTTP/1.1" 200 19369332 "-" "Go-http-client/1.1"
# ...
# 169.254.255.130 - - [08/Mar/2020:13:05:11 +0000] "POST /invocations HTTP/1.1" 200 18816973 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:10 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/7/48/0000000487 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:11 +0000] "POST /invocations HTTP/1.1" 200 18816973 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:12 [warn] 16#16: *405 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/49/0000000493 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:12 +0000] "POST /invocations HTTP/1.1" 200 18198053 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:11 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/48/0000000488 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:12 +0000] "POST /invocations HTTP/1.1" 200 17942152 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:11 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/48/0000000488 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:12 +0000] "POST /invocations HTTP/1.1" 200 17942152 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:12 [warn] 20#20: *410 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/4/49/0000000494 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:12 +0000] "POST /invocations HTTP/1.1" 200 18257786 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:12 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/48/0000000489 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:12 +0000] "POST /invocations HTTP/1.1" 200 18297471 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:12 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/48/0000000489 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:12 +0000] "POST /invocations HTTP/1.1" 200 18297471 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:13 [warn] 16#16: *405 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/5/49/0000000495 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:13 +0000] "POST /invocations HTTP/1.1" 200 18479256 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:14 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/49/0000000490 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 13:05:14 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/49/0000000490 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:14 +0000] "POST /invocations HTTP/1.1" 200 18537482 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:13:05:14 +0000] "POST /invocations HTTP/1.1" 200 18537482 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:14 [warn] 20#20: *410 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/6/49/0000000496 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:14 +0000] "POST /invocations HTTP/1.1" 200 18098633 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:15 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/49/0000000491 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:15 +0000] "POST /invocations HTTP/1.1" 200 18392759 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:15 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/1/49/0000000491 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:15 +0000] "POST /invocations HTTP/1.1" 200 18392759 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:15 [warn] 16#16: *405 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/7/49/0000000497 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:16 +0000] "POST /invocations HTTP/1.1" 200 18230709 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:16 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/49/0000000492 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:16 +0000] "POST /invocations HTTP/1.1" 200 18341422 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:16 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/2/49/0000000492 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:16 +0000] "POST /invocations HTTP/1.1" 200 18341422 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:16 [warn] 20#20: *410 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/49/0000000498 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:16 +0000] "POST /invocations HTTP/1.1" 200 17923479 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:17 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/49/0000000493 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:17 +0000] "POST /invocations HTTP/1.1" 200 18198053 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:17 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/3/49/0000000493 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:17 +0000] "POST /invocations HTTP/1.1" 200 18198053 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:17 [warn] 16#16: *405 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/49/0000000499 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:17 +0000] "POST /invocations HTTP/1.1" 200 17923479 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:18 [warn] 20#20: *410 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/50/0000000500 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:18 +0000] "POST /invocations HTTP/1.1" 200 18393665 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:17 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/4/49/0000000494 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:17 +0000] "POST /invocations HTTP/1.1" 200 18257786 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:17 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/4/49/0000000494 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:17 +0000] "POST /invocations HTTP/1.1" 200 18257786 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:19 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/6/49/0000000496 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 13:05:19 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/6/49/0000000496 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:19 +0000] "POST /invocations HTTP/1.1" 200 18098633 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:20 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/7/49/0000000497 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:19 +0000] "POST /invocations HTTP/1.1" 200 18098633 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:20 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/7/49/0000000497 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:20 +0000] "POST /invocations HTTP/1.1" 200 18230709 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:13:05:20 +0000] "POST /invocations HTTP/1.1" 200 18230709 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:21 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/49/0000000498 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:21 +0000] "POST /invocations HTTP/1.1" 200 17923479 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:21 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/8/49/0000000498 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:21 +0000] "POST /invocations HTTP/1.1" 200 17923479 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:22 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/49/0000000499 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 2020/03/08 13:05:22 [warn] 18#18: *404 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/9/49/0000000499 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:22 +0000] "POST /invocations HTTP/1.1" 200 17923479 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:23 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/50/0000000500 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:23 +0000] "POST /invocations HTTP/1.1" 200 18393665 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [08/Mar/2020:13:05:22 +0000] "POST /invocations HTTP/1.1" 200 17923479 "-" "Go-http-client/1.1"
# 2020/03/08 13:05:23 [warn] 16#16: *413 an upstream response is buffered to a temporary file /var/cache/nginx/proxy_temp/0/50/0000000500 while reading upstream, client: 169.254.255.130, server: , request: "POST /invocations HTTP/1.1", subrequest: "/v1/models/model:predict", upstream: "http://127.0.0.1:10001/v1/models/model:predict", host: "169.254.255.131:8080"
# 169.254.255.130 - - [08/Mar/2020:13:05:23 +0000] "POST /invocations HTTP/1.1" 200 18393665 "-" "Go-http-client/1.1"

# %%
output_path

# %%
# import json
# import io
# from urllib.parse import urlparse

# def get_csv_output_from_s3(s3uri, file_name):
#     parsed_url = urlparse(s3uri)

#     bucket_name = parsed_url.netloc

#     prefix = parsed_url.path[1:]

#     s3 = boto3.resource('s3')
#     obj = s3.Object(bucket_name, '{}/{}'.format(prefix, file_name))

#     return obj.get()["Body"].read().decode('utf-8')

# %%
# output = get_csv_output_from_s3(output_path[:-1], dataset_test_name+'.out')
# j =json.loads(output)
# n =j['predictions']
# df = pd.DataFrame.from_records(n)
# df.head()
